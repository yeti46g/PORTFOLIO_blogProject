# %%
import numpy as np 
import pandas as pd 
import os
from plotly import tools
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly as py
import plotly.graph_objs as go
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)
pd.set_option('display.max_columns', None)
print(os.listdir("data"))
pd.set_option('display.max_columns', None)
import operator
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['survey-results-public.csv', 'survey-results-schema.csv']

# %%
data =pd.read_csv('data/survey-results-public.csv')
schema=pd.read_csv('data/survey-results-schema.csv')

# %%
data.head(100)
# Out:
#     Respondent                                       Professional  \
# 0            1                                            Student
# 1            2                                            Student
# 2            3                             Professional developer
# 3            4  Professional non-developer who sometimes write...
# 4            5                             Professional developer
# 5            6                                            Student
# 6            7  Professional non-developer who sometimes write...
# 7            8                             Professional developer
# 8            9                             Professional developer
# 9           10                             Professional developer
# 10          11  Professional non-developer who sometimes write...
# 11          12                             Professional developer
# 12          13                Used to be a professional developer
# 13          14                             Professional developer
# 14          15                             Professional developer
# 15          16                             Professional developer
# 16          17                             Professional developer
# 17          18                             Professional developer
# 18          19                             Professional developer
# 19          20                             Professional developer
# 20          21                             Professional developer
# 21          22                             Professional developer
# 22          23                             Professional developer
# 23          24                             Professional developer
# 24          25                             Professional developer
# 25          26                             Professional developer
# 26          27                             Professional developer
# 27          28                             Professional developer
# 28          29  Professional non-developer who sometimes write...
# 29          30  Professional non-developer who sometimes write...
# ..         ...                                                ...
# 70          71                             Professional developer
# 71          72                             Professional developer
# 72          73                             Professional developer
# 73          74                             Professional developer
# 74          75                             Professional developer
# 75          76                             Professional developer
# 76          77                             Professional developer
# 77          78                             Professional developer
# 78          79                             Professional developer
# 79          80                             Professional developer
# 80          81                             Professional developer
# 81          82                             Professional developer
# 82          83                             Professional developer
# 83          84                             Professional developer
# 84          85                             Professional developer
# 85          86                             Professional developer
# 86          87                             Professional developer
# 87          88                                            Student
# 88          89                             Professional developer
# 89          90                             Professional developer
# 90          91                             Professional developer
# 91          92                             Professional developer
# 92          93                             Professional developer
# 93          94                             Professional developer
# 94          95                             Professional developer
# 95          96                             Professional developer
# 96          97                             Professional developer
# 97          98                             Professional developer
# 98          99                                            Student
# 99         100                             Professional developer
#
#                                  ProgramHobby         Country      University  \
# 0                                   Yes, both   United States              No
# 1                                   Yes, both  United Kingdom  Yes, full-time
# 2                                   Yes, both  United Kingdom              No
# 3                                   Yes, both   United States              No
# 4                   Yes, I program as a hobby     Switzerland              No
# 5                                   Yes, both     New Zealand  Yes, full-time
# 6                                   Yes, both   United States              No
# 7                                   Yes, both          Poland              No
# 8                   Yes, I program as a hobby        Colombia  Yes, part-time
# 9                   Yes, I program as a hobby          France  Yes, full-time
# 10                  Yes, I program as a hobby   United States              No
# 11                                         No          Canada              No
# 12                  Yes, I program as a hobby  United Kingdom              No
# 13                                  Yes, both         Germany              No
# 14                  Yes, I program as a hobby  United Kingdom              No
# 15                  Yes, I program as a hobby   United States  Yes, part-time
# 16                                  Yes, both  United Kingdom              No
# 17                                  Yes, both   United States  Yes, part-time
# 18                  Yes, I program as a hobby   United States              No
# 19                  Yes, I program as a hobby          Greece              No
# 20                  Yes, I program as a hobby          Brazil              No
# 21                  Yes, I program as a hobby  United Kingdom              No
# 22                                         No          Israel              No
# 23                                  Yes, both           Italy              No
# 24                  Yes, I program as a hobby         Belgium              No
# 25                  Yes, I program as a hobby   United States              No
# 26                                         No           India              No
# 27                  Yes, I program as a hobby   United States              No
# 28                                  Yes, both          Israel              No
# 29                  Yes, I program as a hobby   United States              No
# ..                                        ...             ...             ...
# 70                  Yes, I program as a hobby   United States              No
# 71                                  Yes, both         Finland              No
# 72                                  Yes, both   United States              No
# 73                  Yes, I program as a hobby         Austria              No
# 74                  Yes, I program as a hobby         Germany  Yes, part-time
# 75                                  Yes, both          France              No
# 76                                  Yes, both   United States              No
# 77                  Yes, I program as a hobby  United Kingdom              No
# 78                  Yes, I program as a hobby  United Kingdom              No
# 79                  Yes, I program as a hobby   United States              No
# 80                  Yes, I program as a hobby          Israel              No
# 81                  Yes, I program as a hobby   United States              No
# 82                  Yes, I program as a hobby   United States              No
# 83                                  Yes, both   United States              No
# 84                                  Yes, both          Mexico              No
# 85                                         No          Poland              No
# 86                                         No         Germany              No
# 87                  Yes, I program as a hobby  United Kingdom  Yes, full-time
# 88                                  Yes, both          Brazil  Yes, part-time
# 89                  Yes, I program as a hobby          Brazil              No
# 90                                  Yes, both         Croatia              No
# 91                                  Yes, both         Germany              No
# 92                  Yes, I program as a hobby   United States              No
# 93                  Yes, I program as a hobby          Poland              No
# 94                                  Yes, both           India  Yes, full-time
# 95  Yes, I contribute to open source projects         Germany              No
# 96                                         No   United States              No
# 97                                         No          Turkey              No
# 98                  Yes, I program as a hobby   United States  Yes, full-time
# 99                                  Yes, both   United States              No
#
#                                      EmploymentStatus  \
# 0              Not employed, and not looking for work
# 1                                  Employed part-time
# 2                                  Employed full-time
# 3                                  Employed full-time
# 4                                  Employed full-time
# 5              Not employed, and not looking for work
# 6                                  Employed full-time
# 7                                  Employed full-time
# 8                                  Employed full-time
# 9   Independent contractor, freelancer, or self-em...
# 10                                 Employed full-time
# 11                                 Employed full-time
# 12                 Not employed, but looking for work
# 13                                 Employed full-time
# 14                                 Employed full-time
# 15  Independent contractor, freelancer, or self-em...
# 16             Not employed, and not looking for work
# 17                                 Employed full-time
# 18                                 Employed full-time
# 19                                 Employed full-time
# 20                                 Employed full-time
# 21                                 Employed full-time
# 22                                 Employed full-time
# 23  Independent contractor, freelancer, or self-em...
# 24                                 Employed full-time
# 25                                 Employed full-time
# 26                                 Employed full-time
# 27                                 Employed full-time
# 28                                 Employed full-time
# 29                                 Employed full-time
# ..                                                ...
# 70                                 Employed full-time
# 71                                 Employed full-time
# 72                                 Employed full-time
# 73                                 Employed full-time
# 74                                 Employed part-time
# 75                                 Employed full-time
# 76                                 Employed full-time
# 77                                 Employed full-time
# 78                                 Employed full-time
# 79                                 Employed full-time
# 80  Independent contractor, freelancer, or self-em...
# 81                                 Employed full-time
# 82                                 Employed full-time
# 83                                 Employed full-time
# 84                                 Employed full-time
# 85                                 Employed full-time
# 86                                 Employed full-time
# 87                 Not employed, but looking for work
# 88                                 Employed full-time
# 89                                 Employed full-time
# 90                                 Employed full-time
# 91             Not employed, and not looking for work
# 92                                 Employed full-time
# 93                                 Employed full-time
# 94             Not employed, and not looking for work
# 95                                 Employed full-time
# 96                                 Employed full-time
# 97                                 Employed full-time
# 98                 Not employed, but looking for work
# 99                                 Employed full-time
#
#                                       FormalEducation  \
# 0                                    Secondary school
# 1   Some college/university study without earning ...
# 2                                   Bachelor's degree
# 3                                     Doctoral degree
# 4                                     Master's degree
# 5                                    Secondary school
# 6                                     Master's degree
# 7                                     Master's degree
# 8                                   Bachelor's degree
# 9                                     Master's degree
# 10                                  Bachelor's degree
# 11                                  Bachelor's degree
# 12                                  Bachelor's degree
# 13  Some college/university study without earning ...
# 14                                Professional degree
# 15                          Primary/elementary school
# 16                                   Secondary school
# 17                                  Bachelor's degree
# 18                                  Bachelor's degree
# 19                                    Doctoral degree
# 20                                  Bachelor's degree
# 21                                  Bachelor's degree
# 22                                  Bachelor's degree
# 23                                   Secondary school
# 24                                    Master's degree
# 25                                    Master's degree
# 26                                  Bachelor's degree
# 27                                  Bachelor's degree
# 28  Some college/university study without earning ...
# 29                                  Bachelor's degree
# ..                                                ...
# 70  Some college/university study without earning ...
# 71  Some college/university study without earning ...
# 72  Some college/university study without earning ...
# 73                                    Master's degree
# 74  Some college/university study without earning ...
# 75                                    Master's degree
# 76  Some college/university study without earning ...
# 77                                  Bachelor's degree
# 78                                  Bachelor's degree
# 79                                  Bachelor's degree
# 80  Some college/university study without earning ...
# 81                                  Bachelor's degree
# 82                                  Bachelor's degree
# 83                                    Doctoral degree
# 84                                  Bachelor's degree
# 85                                  Bachelor's degree
# 86                                    Master's degree
# 87                                   Secondary school
# 88  Some college/university study without earning ...
# 89                                  Bachelor's degree
# 90                                  Bachelor's degree
# 91                                    Master's degree
# 92                                    Master's degree
# 93                                  Bachelor's degree
# 94                                   Secondary school
# 95                                  Bachelor's degree
# 96                                  Bachelor's degree
# 97                                  Bachelor's degree
# 98  Some college/university study without earning ...
# 99                                    Master's degree
#
#                                        MajorUndergrad  \
# 0                                                 NaN
# 1            Computer science or software engineering
# 2            Computer science or software engineering
# 3       A non-computer-focused engineering discipline
# 4            Computer science or software engineering
# 5                                                 NaN
# 6       A non-computer-focused engineering discipline
# 7            Computer science or software engineering
# 8            Computer science or software engineering
# 9            Computer science or software engineering
# 10                                   A social science
# 11           Computer science or software engineering
# 12                          Mathematics or statistics
# 13           Computer science or software engineering
# 14  Computer engineering or electrical/electronics...
# 15                                                NaN
# 16                                                NaN
# 17           Computer science or software engineering
# 18           Computer science or software engineering
# 19                                  A natural science
# 20           Computer science or software engineering
# 21                                  A natural science
# 22  Computer engineering or electrical/electronics...
# 23                                                NaN
# 24           Computer science or software engineering
# 25           Computer science or software engineering
# 26           Computer science or software engineering
# 27                              A business discipline
# 28  Computer engineering or electrical/electronics...
# 29                              A business discipline
# ..                                                ...
# 70  Information technology, networking, or system ...
# 71           Computer science or software engineering
# 72           Computer science or software engineering
# 73           Computer science or software engineering
# 74  Computer engineering or electrical/electronics...
# 75                          Mathematics or statistics
# 76  Computer engineering or electrical/electronics...
# 77           Computer science or software engineering
# 78           Computer science or software engineering
# 79  Information technology, networking, or system ...
# 80           Computer science or software engineering
# 81           Computer science or software engineering
# 82                       Fine arts or performing arts
# 83           Computer science or software engineering
# 84           Computer science or software engineering
# 85      A non-computer-focused engineering discipline
# 86           Computer science or software engineering
# 87                                                NaN
# 88           Computer science or software engineering
# 89           Computer science or software engineering
# 90           Computer science or software engineering
# 91           Computer science or software engineering
# 92           Computer science or software engineering
# 93           Computer science or software engineering
# 94                                                NaN
# 95                     Management information systems
# 96           Computer science or software engineering
# 97           Computer science or software engineering
# 98                                  A natural science
# 99           Computer science or software engineering
#
#                                            HomeRemote  \
# 0                                                 NaN
# 1               More than half, but not all, the time
# 2   Less than half the time, but at least one day ...
# 3   Less than half the time, but at least one day ...
# 4                                               Never
# 5                                                 NaN
# 6   Less than half the time, but at least one day ...
# 7   All or almost all the time (I'm full-time remote)
# 8   Less than half the time, but at least one day ...
# 9                                    It's complicated
# 10  All or almost all the time (I'm full-time remote)
# 11                              A few days each month
# 12                                                NaN
# 13  Less than half the time, but at least one day ...
# 14  All or almost all the time (I'm full-time remote)
# 15  All or almost all the time (I'm full-time remote)
# 16                                                NaN
# 17  All or almost all the time (I'm full-time remote)
# 18                              A few days each month
# 19  Less than half the time, but at least one day ...
# 20  Less than half the time, but at least one day ...
# 21                              A few days each month
# 22                              A few days each month
# 23  All or almost all the time (I'm full-time remote)
# 24                                              Never
# 25  Less than half the time, but at least one day ...
# 26                                              Never
# 27                              A few days each month
# 28                              A few days each month
# 29  Less than half the time, but at least one day ...
# ..                                                ...
# 70                              A few days each month
# 71                              A few days each month
# 72  All or almost all the time (I'm full-time remote)
# 73                                              Never
# 74  All or almost all the time (I'm full-time remote)
# 75                                              Never
# 76              More than half, but not all, the time
# 77                                              Never
# 78                              A few days each month
# 79                              A few days each month
# 80  All or almost all the time (I'm full-time remote)
# 81                              A few days each month
# 82                                              Never
# 83                              A few days each month
# 84                              A few days each month
# 85                              A few days each month
# 86                                About half the time
# 87                                                NaN
# 88                                              Never
# 89  All or almost all the time (I'm full-time remote)
# 90                              A few days each month
# 91                                                NaN
# 92                              A few days each month
# 93                                              Never
# 94                                                NaN
# 95                                              Never
# 96                              A few days each month
# 97                              A few days each month
# 98                                                NaN
# 99                                              Never
#
#                  CompanySize  \
# 0                        NaN
# 1         20 to 99 employees
# 2   10,000 or more employees
# 3   10,000 or more employees
# 4         10 to 19 employees
# 5                        NaN
# 6         20 to 99 employees
# 7    Fewer than 10 employees
# 8   5,000 to 9,999 employees
# 9                        NaN
# 10      100 to 499 employees
# 11      100 to 499 employees
# 12                       NaN
# 13   Fewer than 10 employees
# 14  5,000 to 9,999 employees
# 15                       NaN
# 16                       NaN
# 17  1,000 to 4,999 employees
# 18  10,000 or more employees
# 19   Fewer than 10 employees
# 20  10,000 or more employees
# 21        20 to 99 employees
# 22      500 to 999 employees
# 23                       NaN
# 24        20 to 99 employees
# 25  10,000 or more employees
# 26  5,000 to 9,999 employees
# 27      100 to 499 employees
# 28        10 to 19 employees
# 29  10,000 or more employees
# ..                       ...
# 70        20 to 99 employees
# 71        20 to 99 employees
# 72      100 to 499 employees
# 73      500 to 999 employees
# 74        20 to 99 employees
# 75      500 to 999 employees
# 76  1,000 to 4,999 employees
# 77        20 to 99 employees
# 78        20 to 99 employees
# 79        10 to 19 employees
# 80                       NaN
# 81        20 to 99 employees
# 82  10,000 or more employees
# 83  10,000 or more employees
# 84        10 to 19 employees
# 85  10,000 or more employees
# 86      100 to 499 employees
# 87                       NaN
# 88      100 to 499 employees
# 89        20 to 99 employees
# 90        10 to 19 employees
# 91                       NaN
# 92  10,000 or more employees
# 93        20 to 99 employees
# 94                       NaN
# 95  5,000 to 9,999 employees
# 96        10 to 19 employees
# 97      100 to 499 employees
# 98                       NaN
# 99        20 to 99 employees
#
#                                           CompanyType      YearsProgram  \
# 0                                                 NaN      2 to 3 years
# 1   Privately-held limited company, not in startup...     9 to 10 years
# 2                         Publicly-traded corporation  20 or more years
# 3   Non-profit/non-governmental organization or pr...    14 to 15 years
# 4   Privately-held limited company, not in startup...  20 or more years
# 5                                                 NaN      6 to 7 years
# 6       Government agency or public school/university     9 to 10 years
# 7                                Pre-series A startup    10 to 11 years
# 8   Privately-held limited company, not in startup...    13 to 14 years
# 9                                                 NaN    13 to 14 years
# 10                             Venture-funded startup    12 to 13 years
# 11  Privately-held limited company, not in startup...    13 to 14 years
# 12                                                NaN  20 or more years
# 13                             Venture-funded startup    15 to 16 years
# 14                        Publicly-traded corporation  20 or more years
# 15                                                NaN    11 to 12 years
# 16                                                NaN      8 to 9 years
# 17                        Publicly-traded corporation  20 or more years
# 18                        Publicly-traded corporation      2 to 3 years
# 19                             Venture-funded startup    12 to 13 years
# 20  Privately-held limited company, not in startup...      5 to 6 years
# 21  Privately-held limited company, not in startup...  20 or more years
# 22  Privately-held limited company, not in startup...    10 to 11 years
# 23                                                NaN     9 to 10 years
# 24      Government agency or public school/university    18 to 19 years
# 25                        Publicly-traded corporation  20 or more years
# 26                        Publicly-traded corporation    13 to 14 years
# 27                             Venture-funded startup      2 to 3 years
# 28  Privately-held limited company, not in startup...  20 or more years
# 29  Privately-held limited company, not in startup...      5 to 6 years
# ..                                                ...               ...
# 70  Privately-held limited company, not in startup...      2 to 3 years
# 71  Privately-held limited company, not in startup...      8 to 9 years
# 72                             Venture-funded startup  20 or more years
# 73  Privately-held limited company, not in startup...    14 to 15 years
# 74  Privately-held limited company, not in startup...      3 to 4 years
# 75  Privately-held limited company, not in startup...  20 or more years
# 76      Government agency or public school/university  20 or more years
# 77                                       I don't know      6 to 7 years
# 78                                       I don't know      4 to 5 years
# 79  Privately-held limited company, not in startup...  20 or more years
# 80                                                NaN      2 to 3 years
# 81  Sole proprietorship or partnership, not in sta...    17 to 18 years
# 82                        Publicly-traded corporation  20 or more years
# 83                        Publicly-traded corporation  20 or more years
# 84  Privately-held limited company, not in startup...    12 to 13 years
# 85                        Publicly-traded corporation     9 to 10 years
# 86  Privately-held limited company, not in startup...    13 to 14 years
# 87                                                NaN      6 to 7 years
# 88                             I prefer not to answer      8 to 9 years
# 89                             Venture-funded startup    11 to 12 years
# 90  Privately-held limited company, not in startup...      4 to 5 years
# 91                                                NaN  20 or more years
# 92                        Publicly-traded corporation  20 or more years
# 93                                State-owned company      6 to 7 years
# 94                                                NaN      3 to 4 years
# 95  Privately-held limited company, not in startup...     9 to 10 years
# 96      Government agency or public school/university      4 to 5 years
# 97                                       I don't know    14 to 15 years
# 98                                                NaN      3 to 4 years
# 99  Privately-held limited company, not in startup...  20 or more years
#
#        YearsCodedJob YearsCodedJobPast  \
# 0                NaN               NaN
# 1                NaN               NaN
# 2   20 or more years               NaN
# 3      9 to 10 years               NaN
# 4     10 to 11 years               NaN
# 5                NaN               NaN
# 6       8 to 9 years               NaN
# 7       7 to 8 years               NaN
# 8       7 to 8 years               NaN
# 9       8 to 9 years               NaN
# 10    11 to 12 years               NaN
# 11      8 to 9 years               NaN
# 12               NaN    17 to 18 years
# 13    15 to 16 years               NaN
# 14  20 or more years               NaN
# 15      1 to 2 years               NaN
# 16      8 to 9 years               NaN
# 17  20 or more years               NaN
# 18      3 to 4 years               NaN
# 19    12 to 13 years               NaN
# 20  Less than a year               NaN
# 21  20 or more years               NaN
# 22      5 to 6 years               NaN
# 23      7 to 8 years               NaN
# 24     9 to 10 years               NaN
# 25    16 to 17 years               NaN
# 26     9 to 10 years               NaN
# 27  Less than a year               NaN
# 28    13 to 14 years               NaN
# 29      3 to 4 years               NaN
# ..               ...               ...
# 70      1 to 2 years               NaN
# 71      5 to 6 years               NaN
# 72  20 or more years               NaN
# 73    12 to 13 years               NaN
# 74      2 to 3 years               NaN
# 75    16 to 17 years               NaN
# 76  20 or more years               NaN
# 77      2 to 3 years               NaN
# 78      1 to 2 years               NaN
# 79    14 to 15 years               NaN
# 80      2 to 3 years               NaN
# 81    13 to 14 years               NaN
# 82    18 to 19 years               NaN
# 83               NaN               NaN
# 84               NaN               NaN
# 85      2 to 3 years               NaN
# 86    10 to 11 years               NaN
# 87               NaN               NaN
# 88      4 to 5 years               NaN
# 89    11 to 12 years               NaN
# 90      3 to 4 years               NaN
# 91    10 to 11 years               NaN
# 92    15 to 16 years               NaN
# 93      3 to 4 years               NaN
# 94      1 to 2 years               NaN
# 95      4 to 5 years               NaN
# 96      1 to 2 years               NaN
# 97      4 to 5 years               NaN
# 98               NaN               NaN
# 99      7 to 8 years               NaN
#
#                                         DeveloperType  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                               Other
# 3                                                 NaN
# 4   Mobile developer; Graphics programming; Deskto...
# 5                                                 NaN
# 6                                                 NaN
# 7                                       Web developer
# 8                     Web developer; Mobile developer
# 9    Mobile developer; Desktop applications developer
# 10                                                NaN
# 11                                      Web developer
# 12                                                NaN
# 13                                      Web developer
# 14            Embedded applications/devices developer
# 15                     Desktop applications developer
# 16                                      Web developer
# 17  Web developer; Embedded applications/devices d...
# 18                                      Web developer
# 19                              Data scientist; Other
# 20                                      Web developer
# 21  Web developer; Mobile developer; Desktop appli...
# 22                                              Other
# 23                                      Web developer
# 24                               Web developer; Other
# 25                                      Web developer
# 26                    Web developer; Mobile developer
# 27      Web developer; Desktop applications developer
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 70                                      Web developer
# 71  Web developer; Database administrator; Systems...
# 72                                      Web developer
# 73                           DevOps specialist; Other
# 74  Developer with a statistics or mathematics bac...
# 75  Web developer; Mobile developer; Embedded appl...
# 76                                      Web developer
# 77  Web developer; Developer with a statistics or ...
# 78                    Web developer; Mobile developer
# 79  Web developer; Desktop applications developer;...
# 80                                      Web developer
# 81                                      Web developer
# 82  Web developer; Mobile developer; Data scientis...
# 83                                      Web developer
# 84  Web developer; Mobile developer; Database admi...
# 85            Embedded applications/devices developer
# 86                                   Mobile developer
# 87                                                NaN
# 88                                      Web developer
# 89                                      Web developer
# 90                                      Web developer
# 91  Machine learning specialist; Developer with a ...
# 92                    Web developer; Mobile developer
# 93                                      Web developer
# 94  Web developer; Desktop applications developer;...
# 95                                      Web developer
# 96  Web developer; Desktop applications developer;...
# 97                                      Web developer
# 98                                                NaN
# 99   Mobile developer; Desktop applications developer
#
#             WebDeveloperType MobileDeveloperType  \
# 0                        NaN                 NaN
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
# 5                        NaN                 NaN
# 6                        NaN                 NaN
# 7   Full stack Web developer                 NaN
# 8                        NaN                 NaN
# 9                        NaN                 NaN
# 10                       NaN                 NaN
# 11    Back-end Web developer                 NaN
# 12                       NaN                 NaN
# 13  Full stack Web developer                 NaN
# 14                       NaN                 NaN
# 15                       NaN                 NaN
# 16  Full stack Web developer                 NaN
# 17                       NaN                 NaN
# 18  Full stack Web developer                 NaN
# 19                       NaN                 NaN
# 20  Full stack Web developer                 NaN
# 21                       NaN                 NaN
# 22                       NaN                 NaN
# 23  Full stack Web developer                 NaN
# 24                       NaN                 NaN
# 25    Back-end Web developer                 NaN
# 26                       NaN                 NaN
# 27                       NaN                 NaN
# 28                       NaN                 NaN
# 29                       NaN                 NaN
# ..                       ...                 ...
# 70  Full stack Web developer                 NaN
# 71                       NaN                 NaN
# 72  Full stack Web developer                 NaN
# 73                       NaN                 NaN
# 74                       NaN                 NaN
# 75                       NaN                 NaN
# 76  Full stack Web developer                 NaN
# 77                       NaN                 NaN
# 78                       NaN                 NaN
# 79                       NaN                 NaN
# 80  Full stack Web developer                 NaN
# 81  Full stack Web developer                 NaN
# 82                       NaN                 NaN
# 83    Back-end Web developer                 NaN
# 84                       NaN                 NaN
# 85                       NaN                 NaN
# 86                       NaN                 iOS
# 87                       NaN                 NaN
# 88    Back-end Web developer                 NaN
# 89  Full stack Web developer                 NaN
# 90  Full stack Web developer                 NaN
# 91                       NaN                 NaN
# 92                       NaN                 NaN
# 93    Back-end Web developer                 NaN
# 94                       NaN                 NaN
# 95  Full stack Web developer                 NaN
# 96                       NaN                 NaN
# 97  Full stack Web developer                 NaN
# 98                       NaN                 NaN
# 99                       NaN                 NaN
#
#                       NonDeveloperType  CareerSatisfaction  JobSatisfaction  \
# 0                                  NaN                 NaN              NaN
# 1                                  NaN                 NaN              NaN
# 2                                  NaN                 8.0              9.0
# 3                       Data scientist                 6.0              3.0
# 4                                  NaN                 6.0              8.0
# 5                                  NaN                 NaN              NaN
# 6                       Data scientist                 7.0              6.0
# 7                                  NaN                 7.0              7.0
# 8                                  NaN                 6.0              6.0
# 9                                  NaN                 6.0              8.0
# 10                               Other                 8.0              9.0
# 11                                 NaN                 8.0              6.0
# 12                                 NaN                 3.0              NaN
# 13                                 NaN                 8.0              6.0
# 14                                 NaN                 8.0              8.0
# 15                                 NaN                 8.0              8.0
# 16                                 NaN                 6.0              NaN
# 17                                 NaN                 9.0              8.0
# 18                                 NaN                 5.0              3.0
# 19                                 NaN                 8.0              8.0
# 20                                 NaN                 7.0              7.0
# 21                                 NaN                 8.0              8.0
# 22                                 NaN                 8.0              9.0
# 23                                 NaN                 7.0              8.0
# 24                                 NaN                 7.0              9.0
# 25                                 NaN                 7.0              7.0
# 26                                 NaN                 5.0              6.0
# 27                                 NaN                 9.0              9.0
# 28  C-suite executive; Product manager                 8.0              7.0
# 29                               Other                 6.0              6.0
# ..                                 ...                 ...              ...
# 70                                 NaN                 8.0              5.0
# 71                                 NaN                 8.0              6.0
# 72                                 NaN                 8.0              5.0
# 73                                 NaN                 9.0              8.0
# 74                                 NaN                 9.0              9.0
# 75                                 NaN                 6.0              2.0
# 76                                 NaN                10.0              8.0
# 77                                 NaN                 8.0              8.0
# 78                                 NaN                 8.0              8.0
# 79                                 NaN                 7.0              6.0
# 80                                 NaN                10.0             10.0
# 81                                 NaN                 7.0              6.0
# 82                                 NaN                 7.0              8.0
# 83                                 NaN                 6.0              5.0
# 84                                 NaN                10.0             10.0
# 85                                 NaN                 7.0              5.0
# 86                                 NaN                 5.0              3.0
# 87                                 NaN                 NaN              NaN
# 88                                 NaN                 7.0              8.0
# 89                                 NaN                 9.0              9.0
# 90                                 NaN                 8.0              6.0
# 91                                 NaN                 4.0              NaN
# 92                                 NaN                 8.0              8.0
# 93                                 NaN                 6.0              6.0
# 94                                 NaN                 7.0              NaN
# 95                                 NaN                 7.0              7.0
# 96                                 NaN                 8.0              6.0
# 97                                 NaN                 8.0              8.0
# 98                                 NaN                 NaN              NaN
# 99                                 NaN                 8.0              8.0
#
#    ExCoderReturn    ExCoderNotForMe ExCoderBalance     ExCoder10Years  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
# 5            NaN                NaN            NaN                NaN
# 6            NaN                NaN            NaN                NaN
# 7            NaN                NaN            NaN                NaN
# 8            NaN                NaN            NaN                NaN
# 9            NaN                NaN            NaN                NaN
# 10           NaN                NaN            NaN                NaN
# 11           NaN                NaN            NaN                NaN
# 12         Agree  Strongly disagree       Disagree  Strongly disagree
# 13           NaN                NaN            NaN                NaN
# 14           NaN                NaN            NaN                NaN
# 15           NaN                NaN            NaN                NaN
# 16           NaN                NaN            NaN                NaN
# 17           NaN                NaN            NaN                NaN
# 18           NaN                NaN            NaN                NaN
# 19           NaN                NaN            NaN                NaN
# 20           NaN                NaN            NaN                NaN
# 21           NaN                NaN            NaN                NaN
# 22           NaN                NaN            NaN                NaN
# 23           NaN                NaN            NaN                NaN
# 24           NaN                NaN            NaN                NaN
# 25           NaN                NaN            NaN                NaN
# 26           NaN                NaN            NaN                NaN
# 27           NaN                NaN            NaN                NaN
# 28           NaN                NaN            NaN                NaN
# 29           NaN                NaN            NaN                NaN
# ..           ...                ...            ...                ...
# 70           NaN                NaN            NaN                NaN
# 71           NaN                NaN            NaN                NaN
# 72           NaN                NaN            NaN                NaN
# 73           NaN                NaN            NaN                NaN
# 74           NaN                NaN            NaN                NaN
# 75           NaN                NaN            NaN                NaN
# 76           NaN                NaN            NaN                NaN
# 77           NaN                NaN            NaN                NaN
# 78           NaN                NaN            NaN                NaN
# 79           NaN                NaN            NaN                NaN
# 80           NaN                NaN            NaN                NaN
# 81           NaN                NaN            NaN                NaN
# 82           NaN                NaN            NaN                NaN
# 83           NaN                NaN            NaN                NaN
# 84           NaN                NaN            NaN                NaN
# 85           NaN                NaN            NaN                NaN
# 86           NaN                NaN            NaN                NaN
# 87           NaN                NaN            NaN                NaN
# ...
# 20                    NaN     NaN
# 21               Disagree    Male
# 22         Somewhat agree    Male
# 23               Disagree    Male
# 24                    NaN     NaN
# 25               Disagree    Male
# 26                    NaN     NaN
# 27                    NaN     NaN
# 28               Disagree    Male
# 29                    NaN     NaN
# ..                    ...     ...
# 70      Strongly disagree    Male
# 71               Disagree    Male
# 72               Disagree    Male
# 73      Strongly disagree    Male
# 74                    NaN     NaN
# 75               Disagree    Male
# 76               Disagree    Male
# 77                    NaN     NaN
# 78                    NaN     NaN
# 79                    NaN     NaN
# 80                    NaN     NaN
# 81         Somewhat agree    Male
# 82               Disagree    Male
# 83         Somewhat agree    Male
# 84         Somewhat agree    Male
# 85                    NaN     NaN
# 86                    NaN     NaN
# 87                    NaN     NaN
# 88               Disagree    Male
# 89               Disagree    Male
# 90               Disagree    Male
# 91               Disagree    Male
# 92                    NaN     NaN
# 93               Disagree    Male
# 94      Strongly disagree    Male
# 95         Somewhat agree    Male
# 96         Somewhat agree    Male
# 97               Disagree    Male
# 98                    NaN     NaN
# 99               Disagree    Male
#
#                               HighestEducationParents  \
# 0                                         High school
# 1                                   A master's degree
# 2                               A professional degree
# 3                                   A doctoral degree
# 4                                                 NaN
# 5                                 A bachelor's degree
# 6                                   A doctoral degree
# 7                                   A master's degree
# 8                                 A bachelor's degree
# 9                                   A doctoral degree
# 10  Some college/university study, no bachelor's d...
# 11                                                NaN
# 12                                A bachelor's degree
# 13                                  A master's degree
# 14                                        High school
# 15                                  A doctoral degree
# 16                                        High school
# 17                                  A master's degree
# 18                                                NaN
# 19                                  A master's degree
# 20                                                NaN
# 21                                A bachelor's degree
# 22                                A bachelor's degree
# 23                                        High school
# 24                                                NaN
# 25                                  A master's degree
# 26                                                NaN
# 27                                                NaN
# 28                                A bachelor's degree
# 29                                                NaN
# ..                                                ...
# 70                                        High school
# 71  Some college/university study, no bachelor's d...
# 72                                A bachelor's degree
# 73                          Primary/elementary school
# 74                                                NaN
# 75                                  A master's degree
# 76  Some college/university study, no bachelor's d...
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                A bachelor's degree
# 82                                A bachelor's degree
# 83                                  A doctoral degree
# 84                                        High school
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                A bachelor's degree
# 89                                        High school
# 90                                A bachelor's degree
# 91                                  A master's degree
# 92                                                NaN
# 93                                        High school
# 94                                        High school
# 95                                        High school
# 96                                A bachelor's degree
# 97                          Primary/elementary school
# 98                                                NaN
# 99                                  A master's degree
#
#                                                  Race         SurveyLong  \
# 0                        White or of European descent  Strongly disagree
# 1                        White or of European descent     Somewhat agree
# 2                        White or of European descent     Somewhat agree
# 3                        White or of European descent              Agree
# 4                                                 NaN                NaN
# 5                        White or of European descent           Disagree
# 6                        White or of European descent           Disagree
# 7                        White or of European descent              Agree
# 8                           Hispanic or Latino/Latina     Somewhat agree
# 9                        White or of European descent     Somewhat agree
# 10                       White or of European descent  Strongly disagree
# 11                                                NaN                NaN
# 12                       White or of European descent           Disagree
# 13                          Hispanic or Latino/Latina     Somewhat agree
# 14                       White or of European descent     Somewhat agree
# 15                       White or of European descent           Disagree
# 16                       White or of European descent           Disagree
# 17  Native American, Pacific Islander, or Indigeno...           Disagree
# 18                                                NaN                NaN
# 19                                I prefer not to say              Agree
# 20                                                NaN                NaN
# 21                       White or of European descent     Somewhat agree
# 22                       White or of European descent     Strongly agree
# 23                       White or of European descent              Agree
# 24                                                NaN                NaN
# 25                       White or of European descent           Disagree
# 26                                                NaN                NaN
# 27                                                NaN                NaN
# 28                       White or of European descent     Somewhat agree
# 29                                                NaN                NaN
# ..                                                ...                ...
# 70                       White or of European descent           Disagree
# 71                       White or of European descent  Strongly disagree
# 72                       White or of European descent           Disagree
# 73                       White or of European descent     Strongly agree
# 74                                                NaN                NaN
# 75                       White or of European descent           Disagree
# 76                       White or of European descent           Disagree
# 77                                                NaN                NaN
# 78                                                NaN                NaN
# 79                                                NaN                NaN
# 80                                                NaN                NaN
# 81                       White or of European descent           Disagree
# 82                       White or of European descent     Somewhat agree
# 83                       White or of European descent              Agree
# 84  Hispanic or Latino/Latina; Native American, Pa...     Strongly agree
# 85                                                NaN                NaN
# 86                                                NaN                NaN
# 87                                                NaN                NaN
# 88                          Hispanic or Latino/Latina     Strongly agree
# 89                          Hispanic or Latino/Latina     Strongly agree
# 90                       White or of European descent              Agree
# 91                       White or of European descent           Disagree
# 92                                                NaN                NaN
# 93                       White or of European descent     Somewhat agree
# 94                                       I don’t know     Somewhat agree
# 95                       White or of European descent              Agree
# 96                       White or of European descent     Somewhat agree
# 97                       White or of European descent     Somewhat agree
# 98                                                NaN                NaN
# 99                       White or of European descent              Agree
#
#    QuestionsInteresting QuestionsConfusing InterestedAnswers         Salary  \
# 0        Strongly agree           Disagree    Strongly agree            NaN
# 1        Somewhat agree           Disagree    Strongly agree            NaN
# 2                 Agree           Disagree             Agree  113750.000000
# 3                 Agree     Somewhat agree    Strongly agree            NaN
# 4                   NaN                NaN               NaN            NaN
# 5                 Agree           Disagree             Agree            NaN
# 6                 Agree           Disagree             Agree            NaN
# 7        Somewhat agree           Disagree             Agree            NaN
# 8        Strongly agree           Disagree    Strongly agree            NaN
# 9                 Agree           Disagree             Agree            NaN
# 10                Agree  Strongly disagree    Strongly agree            NaN
# 11                  NaN                NaN               NaN            NaN
# 12       Somewhat agree           Disagree             Agree            NaN
# 13                Agree           Disagree    Strongly agree            NaN
# 14                Agree           Disagree             Agree  100000.000000
# 15       Somewhat agree  Strongly disagree             Agree            NaN
# 16                Agree  Strongly disagree    Strongly agree            NaN
# 17                Agree           Disagree             Agree  130000.000000
# 18                  NaN                NaN               NaN   82500.000000
# 19       Somewhat agree           Disagree    Somewhat agree            NaN
# 20                  NaN                NaN               NaN            NaN
# 21       Somewhat agree           Disagree             Agree            NaN
# 22       Somewhat agree     Somewhat agree             Agree  100764.000000
# 23                Agree           Disagree             Agree            NaN
# 24                  NaN                NaN               NaN            NaN
# 25       Strongly agree           Disagree    Strongly agree  175000.000000
# 26                  NaN                NaN               NaN            NaN
# 27                  NaN                NaN               NaN            NaN
# 28       Somewhat agree           Disagree             Agree            NaN
# 29                  NaN                NaN               NaN            NaN
# ..                  ...                ...               ...            ...
# 70       Somewhat agree           Disagree             Agree   65000.000000
# 71       Somewhat agree           Disagree             Agree            NaN
# 72       Somewhat agree  Strongly disagree             Agree  120000.000000
# 73             Disagree           Disagree    Strongly agree            NaN
# 74                  NaN                NaN               NaN            NaN
# 75                Agree           Disagree             Agree   46236.559140
# 76       Somewhat agree           Disagree    Somewhat agree   96283.000000
# 77                  NaN                NaN               NaN            NaN
# 78                  NaN                NaN               NaN            NaN
# 79                  NaN                NaN               NaN            NaN
# 80                  NaN                NaN               NaN            NaN
# 81       Somewhat agree           Disagree    Strongly agree  110000.000000
# 82                Agree  Strongly disagree             Agree            NaN
# 83       Somewhat agree           Disagree             Agree  165000.000000
# 84                Agree     Somewhat agree             Agree            NaN
# 85                  NaN                NaN               NaN            NaN
# 86                  NaN                NaN               NaN            NaN
# 87                  NaN                NaN               NaN            NaN
# 88       Strongly agree  Strongly disagree    Strongly agree            NaN
# 89       Somewhat agree           Disagree             Agree  113694.267516
# 90       Somewhat agree           Disagree          Disagree   38600.000000
# 91       Somewhat agree  Strongly disagree    Somewhat agree            NaN
# 92                  NaN                NaN               NaN            NaN
# 93                Agree           Disagree             Agree            NaN
# 94                Agree           Disagree             Agree            NaN
# 95       Somewhat agree           Disagree             Agree   53763.440860
# 96                Agree  Strongly disagree    Strongly agree            NaN
# 97       Somewhat agree           Disagree    Strongly agree   27548.209366
# 98                  NaN                NaN               NaN            NaN
# 99       Somewhat agree              Agree    Strongly agree  109400.000000
#
#     ExpectedSalary
# 0              NaN
# 1          37500.0
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# ..             ...
# 70             NaN
# 71             NaN
# 72             NaN
# 73             NaN
# 74             NaN
# 75             NaN
# 76             NaN
# 77             NaN
# 78             NaN
# 79             NaN
# 80             NaN
# 81             NaN
# 82             NaN
# 83             NaN
# 84             NaN
# 85             NaN
# 86             NaN
# 87             NaN
# 88             NaN
# 89             NaN
# 90             NaN
# 91             NaN
# 92             NaN
# 93             NaN
# 94             NaN
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
#
# [100 rows x 154 columns]

# %%
data['Country'].value_counts()
# Out:
# United States                     11455
# India                              5197
# United Kingdom                     4395
# Germany                            4143
# Canada                             2233
# France                             1740
# Poland                             1290
# Australia                           913
# Russian Federation                  873
# Spain                               864
# Netherlands                         855
# Italy                               781
# Brazil                              777
# Sweden                              611
# Switzerland                         595
# Israel                              575
# Romania                             561
# Iran                                507
# Austria                             477
# Pakistan                            454
# Czech Republic                      411
# Belgium                             404
# South Africa                        380
# Turkey                              363
# Ukraine                             356
# Mexico                              351
# Ireland                             345
# Hungary                             332
# Philippines                         328
# Slovenia                            303
#                                   ...
# Virgin Islands (British)              2
# Suriname                              2
# Seychelles                            1
# Monaco                                1
# S. Georgia & S. Sandwich Isls.        1
# British Indian Ocean Territory        1
# Gibraltar                             1
# Macau                                 1
# Montserrat                            1
# Burkina Faso                          1
# Lesotho                               1
# Heard and McDonald Islands            1
# Christmas Island                      1
# Cape Verde                            1
# French Guyana                         1
# Vatican City State                    1
# Turkmenistan                          1
# Djibouti                              1
# Mali                                  1
# Comoros                               1
# Bahamas                               1
# Northern Mariana Islands              1
# Falkland Islands                      1
# Chad                                  1
# Cook Islands                          1
# Saint Helena                          1
# Guinea                                1
# Pitcairn Island                       1
# Gabon                                 1
# Guam                                  1
# Name: Country, Length: 201, dtype: int64
